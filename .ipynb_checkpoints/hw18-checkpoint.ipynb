# %%
# !pip install ipython-sql

# %load_ext sql
# !env | grep POST
import os
USER = os.environ['POSTGRESQL_USER']
PASSWORD = os.environ['POSTGRESQL_PASSWORD']
POSTGRESQL_HOST = '10.129.0.25'
DBASE_NAME = 'demo'

CONNECT_DATA = 'postgresql://{}:{}@{}/{}'.format(
    USER,
    PASSWORD,
    POSTGRESQL_HOST,
    DBASE_NAME
)
# Out:
# ...
# WARNING: There was an error checking the latest version of pip.
# POSTGRESQL_USER=reader
# POSTGRESQL_PASSWORD=Miba2021

# %%
# %%sql $CONNECT_DATA
# SELECT ticket_no, Count(flight_id) c
# FROM ticket_flights
# group by ticket_no
# HAVING COUNT(*)>3
# order by c asc
# LIMIT 100;
# Out:
# 100 rows affected.
# [('0005432312164', 4),
#  ('0005432312165', 4),
#  ('0005432312166', 4),
#  ('0005432312167', 4),
#  ('0005432312168', 4),
#  ('0005432312169', 4),
#  ('0005432312170', 4),
#  ('0005432312171', 4),
#  ('0005432312172', 4),
#  ('0005432312173', 4),
#  ('0005432312174', 4),
#  ('0005432312175', 4),
#  ('0005432312176', 4),
#  ('0005432312177', 4),
#  ('0005432312178', 4),
#  ('0005432312179', 4),
#  ('0005432312180', 4),
#  ('0005432312181', 4),
#  ('0005432312182', 4),
#  ('0005432312183', 4),
#  ('0005432312184', 4),
#  ('0005432312185', 4),
#  ('0005432312186', 4),
#  ('0005432312187', 4),
#  ('0005432312188', 4),
#  ('0005432312189', 4),
#  ('0005432312190', 4),
#  ('0005432312191', 4),
#  ('0005432312192', 4),
#  ('0005432312193', 4),
#  ('0005432312194', 4),
#  ('0005432312195', 4),
#  ('0005432312196', 4),
#  ('0005432312197', 4),
#  ('0005432312198', 4),
#  ('0005432312199', 4),
#  ('0005432312200', 4),
#  ('0005432312201', 4),
#  ('0005432312202', 4),
# ...

# %%
# %%sql $CONNECT_DATA
# SELECT ticket_no, Count(flight_id) c
# FROM ticket_flights
# group by ticket_no
# HAVING COUNT(*)=5
# order by c asc
# LIMIT 100;
# Out:
# 54 rows affected.
# [('0005432658632', 5),
#  ('0005432658642', 5),
#  ('0005432658643', 5),
#  ('0005432658644', 5),
#  ('0005432658645', 5),
#  ('0005432658647', 5),
#  ('0005432658648', 5),
#  ('0005432658649', 5),
#  ('0005432658650', 5),
#  ('0005432658651', 5),
#  ('0005432661960', 5),
#  ('0005432661965', 5),
#  ('0005432661975', 5),
#  ('0005432661978', 5),
#  ('0005432661979', 5),
#  ('0005432661980', 5),
#  ('0005432661983', 5),
#  ('0005432661987', 5),
#  ('0005432661988', 5),
#  ('0005432664204', 5),
#  ('0005432664205', 5),
#  ('0005432664206', 5),
#  ('0005432665316', 5),
#  ('0005432665317', 5),
#  ('0005432665318', 5),
#  ('0005432665320', 5),
#  ('0005432665321', 5),
#  ('0005432665324', 5),
#  ('0005432665325', 5),
#  ('0005432665326', 5),
#  ('0005432665327', 5),
#  ('0005432665328', 5),
#  ('0005432665331', 5),
#  ('0005432665332', 5),
#  ('0005432665333', 5),
#  ('0005433124522', 5),
#  ('0005433124543', 5),
#  ('0005433124544', 5),
#  ('0005433194999', 5),
# ...

# %%
# !pip install ipython-sql

# %load_ext sql
import psycopg2
with psycopg2.connect(
    dbname='jovyan'
) as conn:
    with conn.cursor() as cur:
        cur.execute('SELECT datname FROM pg_database')
        records = cur.fetchall()
        
print(records)
# Out:
# ...
# WARNING: There was an error checking the latest version of pip.
# [('postgres',), ('jovyan',), ('template1',), ('template0',)]

# %%
# %%sql postgresql:///jovyan
# CREATE TABLE Employes (
#     EMPLOYEE_ID varchar(20) NOT NULL,
#     FIRST_NAME text NOT NULL,
#     LAST_NAME text NOT NULL,
#     HIRE_DATE text NOT NULL,
#     JOB_ID text NOT NULL,
#     MANAGER_ID varchar(20) NOT NULL,
#     DEPARTMENT_ID varchar(20) NOT NULL
# );
# Out:
# (psycopg2.errors.DuplicateTable) relation "employes" already exists
#
# [SQL: CREATE TABLE Employes (
#     EMPLOYEE_ID varchar(20) NOT NULL,
#     FIRST_NAME text NOT NULL,
#     LAST_NAME text NOT NULL,
#     HIRE_DATE text NOT NULL,
#     JOB_ID text NOT NULL,
#     MANAGER_ID varchar(20) NOT NULL,
#     DEPARTMENT_ID varchar(20) NOT NULL
# );]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# %%sql postgresql:///jovyan
# CREATE TABLE Departments (
#     DEPARTMENT_ID varchar(20) NOT NULL,
#     DEPARTMENT_NAME text NOT NULL,
#     MANAGER_ID text NOT NULL
# );
# Out:
# (psycopg2.errors.DuplicateTable) relation "departments" already exists
#
# [SQL: CREATE TABLE Departments (
#     DEPARTMENT_ID varchar(20) NOT NULL,
#     DEPARTMENT_NAME text NOT NULL,
#     MANAGER_ID text NOT NULL
# );]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# %%sql postgresql:///jovyan
# INSERT INTO Employes VALUES (100, 'Steven', 'King', '1987-06-17', 'AD_PRES', 0, 90)
# INSERT INTO Employes VALUES (101, 'Neena', 'Kochhar', '1987-06-18', 'AD_VP', 100, 90)
# INSERT INTO Employes VALUES (102, 'Lex', 'DeHaan', '1987-06-19', 'AD_VP', 100, 90),
# INSERT INTO Employes VALUES (103, 'Alexander', 'Hunold', '1987-06-20', 'IT_PROG', 102, 60),
# INSERT INTO Employes VALUES (107, 'Diana', 'Lorentz', '1987-06-24', 'IT_PROG', 103, 60),
# INSERT INTO Employes VALUES (108, 'Nancy', 'Greenberg', '1987-06-25', 'FI_MGR', 101, 100),
# INSERT INTO Employes VALUES (109, 'Daniel' ,'Faviet', '1987-06-26', 'FI_ACCOUNT', 108, 100),
# INSERT INTO Employes VALUES (114, 'Den', 'Raphaely', '1987-07-01', 'PU_MAN', 110, 30),
# INSERT INTO Employes VALUES (118, 'Guy', 'Himuro', '1987-07-05', 'PU_CLERK', 114, 30),
# INSERT INTO Employes VALUES (144, 'Peter', 'Vargas', '1987-07-31', 'PU_CLERK', 114, 50),
# INSERT INTO Employes VALUES (145,'John', 'Russell', '1987-08-01', 'ST_CLERK' , 100, 80),
# INSERT INTO Employes VALUES (146, 'Karen', 'Partners', '1987-08-02', 'SA_MAN', 100, 80);
# Out:
# (psycopg2.errors.SyntaxError) syntax error at or near "INSERT"
# LINE 2: INSERT INTO Employes VALUES (101, Neena', Kochhar 1987-06-18...
#         ^
#
# [SQL: INSERT INTO Employes VALUES (100, 'Steven', 'King', '1987-06-17', 'AD_PRES', 0, 90)
# INSERT INTO Employes VALUES (101, Neena', Kochhar	1987-06-18	AD_VP	100	90)
# INSERT INTO Employes VALUES (102, Lex	DeHaan	1987-06-19	AD_VP	100	90)
# INSERT INTO Employes VALUES (103, Alexander	Hunold	1987-06-20	IT_PROG	102	60)
# INSERT INTO Employes VALUES (107, Diana	Lorentz	1987-06-24	IT_PROG	103	60)
# INSERT INTO Employes VALUES (108, Nancy	Greenberg	1987-06-25	FI_MGR	101	100)
# INSERT INTO Employes VALUES (109, Daniel	Faviet	1987-06-26	FI_ACCOUNT	108	100)
# INSERT INTO Employes VALUES (114, Den	Raphaely	1987-07-01	PU_MAN	100	30)
# INSERT INTO Employes VALUES (118, Guy	Himuro	1987-07-05	PU_CLERK	114	30)
# INSERT INTO Employes VALUES (144, Peter	Vargas	1987-07-31	ST_CLERK	114	50)
# ...

# %%
# %%sql postgresql:///jovyan
# INSERT INTO Departments VALUES (10	Administration	200)
# INSERT INTO Departments VALUES (30		Purchasing	114)
# INSERT INTO Departments VALUES (40		HumanResources	203)
# INSERT INTO Departments VALUES (50		Shipping	121)
# INSERT INTO Departments VALUES (60		IT	103)
# INSERT INTO Departments VALUES (70	PublicRelations	204)
# INSERT INTO Departments VALUES (80	Sales	145)
# INSERT INTO Departments VALUES (90		Executive	100)
# INSERT INTO Departments VALUES (100	Finance	108)
# INSERT INTO Departments VALUES (110	Accounting	205)
# Out:
# 1 rows affected.
# []

# %%
# %%sql postgresql:///jovyan
# select * from Employes
# Out:
# 0 rows affected.
# []

# %%
# %%sql postgresql:///jovyan
# SELECT department_id from Employes
# Out:
# 1 rows affected.
# [('90',)]
